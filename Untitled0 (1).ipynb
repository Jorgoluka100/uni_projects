# %%
print("I love my job")
# Out:
# I love my job

# %%
x = 1
if (x== 1):
  print(":)")
elif (x != 1):
  print(":(")
else:
  print("?")

print("fefwe")
# Out:
# :)
# fefwe

# %%
myName = "Jorgo"
print (myName)
# Out:
# Jorgo

# %%
ourGroup = ["Frank", "Jorgo", "Amina", "IndianGuy", "Jaden"]
jadenInGroup = False
for x in ourGroup:
  if (x == "Jaden" and jadenInGroup == False): continue
  print(x)
# Out:
# Frank
# Jorgo
# Amina
# IndianGuy

# %%
groupMembersSkills = {'Frank' : "programming", 'Jorgo' : "events", 'Amina' : 'presentation',
                      'IndianGuy' : 'softwareEngineering'}
for key in groupMembersSkills:
  print(key + " is good at " + groupMembersSkills[key])
# Out:
# Frank is good at programming
# Jorgo is good at events
# Amina is good at presentation
# IndianGuy is good at softwareEngineering

# %%
list = [3,6,9,12]
print(type(list))
# Out:
# <class 'list'>

# %%
myName = input ('What is your name?')
print ('Hi ' + myName)
# Out:
# What is your name?Jorgo
# Hi Jorgo
