# %% [markdown]
# # ModelWatch — Drift & Retraining Monitor
# Run the production-monitoring simulation from a clean Colab runtime. It checks feature drift, performance, calibration, subgroup summaries and a green/amber/red action policy.

# %%
# !git clone -q https://github.com/Jorgoluka100/uni_projects.git /content/uni_projects
# %cd /content/uni_projects
# !pip -q install numpy pandas scipy scikit-learn joblib
# !python projects/model_watch/run.py --self-test
# !python projects/model_watch/run.py --output-dir /content/modelwatch_artifacts

# %%
from pathlib import Path
print(Path('/content/modelwatch_artifacts/verification.json').read_text())
