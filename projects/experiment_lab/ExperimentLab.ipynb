# %% [markdown]
# # ExperimentLab — Experiment Decision Engine
# Run the CUPED, bootstrap, guardrail and power-analysis workflow from a clean Colab runtime. The data are synthetic so the true treatment effect is known.

# %%
# !git clone -q https://github.com/Jorgoluka100/uni_projects.git /content/uni_projects
# %cd /content/uni_projects
# !pip -q install numpy pandas scipy
# !python projects/experiment_lab/run.py --self-test
# !python projects/experiment_lab/run.py --output-dir /content/experimentlab_artifacts

# %%
from pathlib import Path
print(Path('/content/experimentlab_artifacts/verification.json').read_text())
