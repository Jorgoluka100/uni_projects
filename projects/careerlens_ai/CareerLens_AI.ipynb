# %% [markdown]
# # CareerLens AI — Job Fit & Skill-Gap Retrieval
# Run the verified retrieval pipeline from a clean Colab runtime. The built-in benchmark is synthetic and demonstrates ranking methodology, not hiring-market accuracy.

# %%
# !git clone -q https://github.com/Jorgoluka100/uni_projects.git /content/uni_projects
# %cd /content/uni_projects
# !pip -q install numpy pandas scikit-learn
# !python projects/careerlens_ai/run.py --self-test
# !python projects/careerlens_ai/run.py --output-dir /content/careerlens_artifacts

# %%
from pathlib import Path
print(Path('/content/careerlens_artifacts/verification.json').read_text())
