# %% [markdown]
# # CareerLens AI — Project Notebook
#
# Notebook companion for the job-matching / information-retrieval project. The ranking implementation remains in Python source files; this notebook exposes the project structure and results for interactive review.

# %%
from pathlib import Path
import json
PROJECT=Path('projects/careerlens_ai')
if not PROJECT.exists(): PROJECT=Path.cwd()
print('Python files:')
for path in sorted(PROJECT.rglob('*.py')): print(' -',path)

# %%
readme=PROJECT/'README.md'
if readme.exists(): print(readme.read_text(encoding='utf-8')[:12000])

# %%
for path in sorted(PROJECT.rglob('*.json')):
    print('\n---',path,'---')
    try: print(json.dumps(json.loads(path.read_text(encoding='utf-8')),indent=2)[:8000])
    except Exception: pass

# %% [markdown]
# ## What to discuss
#
# NLP / information retrieval, candidate-job similarity, ranking, skill matches/gaps, evaluation and explanation of retrieved results. The tested Python project remains authoritative.
