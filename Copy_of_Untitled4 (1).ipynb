# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
#import numpy as np

# %%
# read csv file, and assign it to the variable
data = pd.read_csv("heatstroke.csv")
data
# Out:
#        id    hrv_mean     hrv_std  hrv_entropy    experiment     Task  \
# 0       1  831.683168  252.279992     4.572689  Experiment 8   Typing
# 1       1  834.558824  252.698300     4.582562  Experiment 8   Typing
# 2       1  834.558824  252.698300     4.582562  Experiment 8   Typing
# 3       1  834.467822  253.944537     4.572286  Experiment 8   Typing
# 4       1  834.467822  253.944537     4.572286  Experiment 8   Typing
# ...    ..         ...         ...          ...           ...      ...
# 81209   1  771.639934  112.190709     5.410363  Experiment 4  Reading
# 81210   1  772.777778  111.130988     5.406176  Experiment 4  Reading
# 81211   1  772.777778  111.130988     5.406176  Experiment 4  Reading
# 81212   1  771.432522  112.705969     5.410239  Experiment 4  Reading
# 81213   1  771.432522  112.705969     5.410239  Experiment 4  Reading
#
#        Temperature Thermal sensation Personal Thermal Assessment
# ...

# %%
# Drop columns from the table
#task1 = ['experiment', 'Task', 'Thermal sensation', 'Personal Thermal Assessment']
#data1 = data.drop(task1, axis=1)
#data1
# Out:
#        id    hrv_mean     hrv_std  hrv_entropy  Temperature
# 0       1  831.683168  252.279992     4.572689           27
# 1       1  834.558824  252.698300     4.582562           27
# 2       1  834.558824  252.698300     4.582562           27
# 3       1  834.467822  253.944537     4.572286           27
# 4       1  834.467822  253.944537     4.572286           27
# ...    ..         ...         ...          ...          ...
# 81209   1  771.639934  112.190709     5.410363           32
# 81210   1  772.777778  111.130988     5.406176           32
# 81211   1  772.777778  111.130988     5.406176           32
# 81212   1  771.432522  112.705969     5.410239           32
# 81213   1  771.432522  112.705969     5.410239           32
#
# [81214 rows x 5 columns]

# %%
# converting text from column values to numbers
string_columns = ["experiment", "Task", "Thermal sensation", "Personal Thermal Assessment"]
# for loop that iterates through all columns from string_columns one by one
for column in string_columns:
  data[column] = LabelEncoder().fit_transform(data[column])

data
# Out:
#        id    hrv_mean     hrv_std  hrv_entropy  experiment  Task  Temperature  \
# 0       1  831.683168  252.279992     4.572689           8     2           27
# 1       1  834.558824  252.698300     4.582562           8     2           27
# 2       1  834.558824  252.698300     4.582562           8     2           27
# 3       1  834.467822  253.944537     4.572286           8     2           27
# 4       1  834.467822  253.944537     4.572286           8     2           27
# ...    ..         ...         ...          ...         ...   ...          ...
# 81209   1  771.639934  112.190709     5.410363           3     1           32
# 81210   1  772.777778  111.130988     5.406176           3     1           32
# 81211   1  772.777778  111.130988     5.406176           3     1           32
# 81212   1  771.432522  112.705969     5.410239           3     1           32
# 81213   1  771.432522  112.705969     5.410239           3     1           32
#
# ...

# %%
# specify 2 columns that you want to compare from dataset and assign it to the variable
hrv_mean_Temperature_data = data.iloc[:, [1,6 ] ]
hrv_std_Temperature_data  = data.iloc[:, [2,6 ] ]
hrv_entropy_Thermal_sensation_data  = data.iloc[:, [3,7 ] ]
hrv_std_Personal_Thermal_Assessment_data = data.iloc[:, [2,8 ] ]
Task_Personal_Thermal_Assessment_data = data.iloc[:, [5,8 ] ]

# %%
# Compare hrv_mean with temperature data using scatterplot
sns.scatterplot(hrv_mean_Temperature_data, x = "hrv_mean", y = "Temperature")
plt.title("hrv_mean and Temperature comparison")
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compare hrv_mean and temperature comparison data using line graph
hrv_mean_Temperature_data.plot(kind='line', figsize=(8, 4), title='hrv_mean and Temperature comparison')
plt.xlabel("ID")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
# Compare hrv_std with temperature data using scatterplot
sns.scatterplot(hrv_std_Temperature_data, x = "hrv_std", y = "Temperature")
plt.title("hrv_std and Personal Temperature comparison")

# %%
# Compare hrv_std and Temperature comparison data using line graph
hrv_std_Temperature_data.plot(kind='line', figsize=(8, 4), title='hrv_std and Temperature comparison')
plt.xlabel("ID")
plt.ylabel("Value")

# %%
# Compare hrv_entropy with thermal_sensation data using scatterplot
sns.scatterplot(hrv_entropy_Thermal_sensation_data, x = "hrv_entropy", y = "Thermal sensation")
plt.title("hrv_entropy and Personal Thermal sensation comparison")

# %%
# Compare hrv_entropy and Thermal sensation data using line graph
hrv_entropy_Thermal_sensation_data.plot(kind='line', figsize=(8, 4), title='hrv_entropy and Thermal sensation')
plt.xlabel("ID")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
# Compare hrv_std and Personal_Thermal_Assessment data using scatterplot
sns.scatterplot(hrv_std_Personal_Thermal_Assessment_data, x = "hrv_std", y = "Personal Thermal Assessment")
plt.title("hrv_std and Personal Thermal Assessment comparison")

# %%
# Compare hrv_std and Personal Thermal Assessment data using line graph
hrv_std_Personal_Thermal_Assessment_data.plot(kind='line', figsize=(8, 4), title='hrv_std and Personal Thermal Assessment')
plt.xlabel("ID")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
# Compare hrv_entropy and Thermal_sensation data using scatterplot
sns.scatterplot(hrv_entropy_Thermal_sensation_data, x = "hrv_entropy", y = "Thermal sensation")
plt.title("hrv_entropy and Thermal sensation comparison")

# %%
# Compare hrv_entropy and Thermal_sensation data using line graph
hrv_entropy_Thermal_sensation_data.plot(kind='line', figsize=(8, 4), title='hrv_entropy and Thermal sensation')
plt.xlabel("ID")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
# assign KMeans class to a variable
data_KMeans = KMeans()

# The K-Elbow Visualizer implements the "elbow" method of selecting the optimal number of clusters for K-means clustering
KElbowVisualizer(data_KMeans, k = (1,11)).fit(hrv_mean_Temperature_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
