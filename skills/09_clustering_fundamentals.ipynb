# %% [markdown]
# # Clustering Fundamentals
# A compact unsupervised-learning project showing scaling, candidate-k comparison, silhouette-based selection and cluster interpretation.

# %%
from pathlib import Path
source = Path('skills/09_clustering_fundamentals.py')
exec(compile(source.read_text(), str(source), 'exec'))
