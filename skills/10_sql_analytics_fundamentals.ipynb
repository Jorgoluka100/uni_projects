# %% [markdown]
# # SQL Analytics Fundamentals
# A compact analyst project covering joins, aggregation, CTEs and a window function before moving to the larger e-commerce SQL warehouse project.

# %%
from pathlib import Path
source = Path('skills/10_sql_analytics_fundamentals.py')
exec(compile(source.read_text(), str(source), 'exec'))
